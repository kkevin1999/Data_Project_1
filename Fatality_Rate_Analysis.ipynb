# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path

data_file = Path("Resources/United_States_COVID-19_Cases_and_Deaths_by_State_over_Time_-_ARCHIVED.csv")
data_df = pd.read_csv(data_file)
data_df
# Out:
#       submission_date state  tot_cases  conf_cases  prob_cases  new_case  \
# 0          03/11/2021    KS     297229    241035.0     56194.0         0
# 1          12/01/2021    ND     163565    135705.0     27860.0       589
# 2          01/02/2022    AS         11         NaN         NaN         0
# 3          11/22/2021    AL     841461    620483.0    220978.0       703
# 4          05/30/2022    AK     251425         NaN         NaN         0
# ...               ...   ...        ...         ...         ...       ...
# 60055      02/09/2021    TX    2504556         NaN         NaN     13329
# 60056      11/20/2020    FL     913561         NaN         NaN      8217
# 60057      08/17/2020    NM      23500         NaN         NaN        92
# 60058      06/17/2020    MS      24223     24038.0       185.0       521
# 60059      05/07/2022    MA    1779829   1638144.0    141685.0         0
#
#        pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# ...

# %%
data_df["submission_date"] = pd.to_datetime(data_df["submission_date"])

# %%
data_df.dtypes
# Out:
# submission_date    datetime64[ns]
# state                      object
# tot_cases                   int64
# conf_cases                float64
# prob_cases                float64
# new_case                    int64
# pnew_case                 float64
# tot_death                   int64
# conf_death                float64
# prob_death                float64
# new_death                   int64
# pnew_death                float64
# created_at                 object
# consent_cases              object
# consent_deaths             object
# dtype: object

# %%
latest_df = data_df.loc[data_df["submission_date"] == "2022-10-18"] 
latest_df
# Out:
#       submission_date state  tot_cases  conf_cases  prob_cases  new_case  \
# 295        2022-10-18    IA     861010         NaN         NaN       844
# 366        2022-10-18    NY    3275131         NaN         NaN      1660
# 390        2022-10-18    NM     623179         NaN         NaN       266
# 683        2022-10-18    FL    7145833         NaN         NaN      1661
# 4666       2022-10-18    MP      13202     13202.0         0.0         0
# 7238       2022-10-18    PW       5490         NaN         NaN         0
# 9774       2022-10-18    OK    1205519    857887.0    347632.0         0
# 10159      2022-10-18    SD     262837         NaN         NaN         0
# 10243      2022-10-18    ND     271085    199512.0     71573.0         0
# 10576      2022-10-18    PR     969066    415637.0    553429.0       159
# 11654      2022-10-18    TN    2351660   1737249.0    614411.0         0
# 14382      2022-10-18    HI     349598         NaN         NaN         0
# ...

# %%
cleaned_df = latest_df.groupby(["state", "tot_cases", "tot_death"])["submission_date"].max().reset_index()
cleaned_df
# Out:
#    state  tot_cases  tot_death submission_date
# 0     AK     284076       1356      2022-10-18
# 1     AL    1530803      20526      2022-10-18
# 2     AR     956424      12386      2022-10-18
# 3     AS       8251         34      2022-10-18
# 4     AZ    2277635      31455      2022-10-18
# 5     CA   11309237      95604      2022-10-18
# 6     CO    1665451      13373      2022-10-18
# 7     CT     907038      11420      2022-10-18
# 8     DC     169149       1392      2022-10-18
# 9     DE     311538       3136      2022-10-18
# 10    FL    7145833      82065      2022-10-18
# 11   FSM      22193         55      2022-10-18
# 12    GA    2913382      40448      2022-10-18
# 13    GU      58703        401      2022-10-18
# 14    HI     349598       1687      2022-10-18
# 15    IA     861010      10152      2022-10-18
# 16    ID     498082       5198      2022-10-18
# 17    IL    3789532      39867      2022-10-18
# 18    IN    1930022      24816      2022-10-18
# ...

# %%
for i in cleaned_df:
    fatal_pct = (cleaned_df["tot_death"] / cleaned_df["tot_cases"]) * 100
    
cleaned_df["% of cases fatal"] = fatal_pct
cleaned_df
# Out:
#    state  tot_cases  tot_death submission_date  % of cases fatal
# 0     AK     284076       1356      2022-10-18          0.477337
# 1     AL    1530803      20526      2022-10-18          1.340865
# 2     AR     956424      12386      2022-10-18          1.295032
# 3     AS       8251         34      2022-10-18          0.412071
# 4     AZ    2277635      31455      2022-10-18          1.381038
# 5     CA   11309237      95604      2022-10-18          0.845362
# 6     CO    1665451      13373      2022-10-18          0.802966
# 7     CT     907038      11420      2022-10-18          1.259043
# 8     DC     169149       1392      2022-10-18          0.822943
# 9     DE     311538       3136      2022-10-18          1.006619
# 10    FL    7145833      82065      2022-10-18          1.148432
# 11   FSM      22193         55      2022-10-18          0.247826
# 12    GA    2913382      40448      2022-10-18          1.388352
# ...

# %%
cleaned_df = cleaned_df.drop(3)
cleaned_df = cleaned_df.drop(11)
cleaned_df = cleaned_df.drop(13)
cleaned_df = cleaned_df.drop(28)
cleaned_df = cleaned_df.drop(39)
cleaned_df = cleaned_df.drop(44)
cleaned_df = cleaned_df.drop(45)
cleaned_df = cleaned_df.drop(47)
cleaned_df = cleaned_df.drop(54)

cleaned_df
# Out:
#    state  tot_cases  tot_death submission_date  % of cases fatal
# 0     AK     284076       1356      2022-10-18          0.477337
# 1     AL    1530803      20526      2022-10-18          1.340865
# 2     AR     956424      12386      2022-10-18          1.295032
# 4     AZ    2277635      31455      2022-10-18          1.381038
# 5     CA   11309237      95604      2022-10-18          0.845362
# 6     CO    1665451      13373      2022-10-18          0.802966
# 7     CT     907038      11420      2022-10-18          1.259043
# 8     DC     169149       1392      2022-10-18          0.822943
# 9     DE     311538       3136      2022-10-18          1.006619
# 10    FL    7145833      82065      2022-10-18          1.148432
# 12    GA    2913382      40448      2022-10-18          1.388352
# 14    HI     349598       1687      2022-10-18          0.482554
# 15    IA     861010      10152      2022-10-18          1.179080
# ...

# %%
sorted_df = cleaned_df.sort_values(["% of cases fatal"], ascending = False).reset_index(drop = True)
sorted_df
# Out:
#    state  tot_cases  tot_death submission_date  % of cases fatal
# 0     PA    3280190      47442      2022-10-18          1.446319
# 1     MS     930438      12945      2022-10-18          1.391280
# 2     GA    2913382      40448      2022-10-18          1.388352
# 3     AZ    2277635      31455      2022-10-18          1.381038
# 4     NM     623179       8601      2022-10-18          1.380181
# 5     MI    2874009      39092      2022-10-18          1.360191
# 6     NV     850204      11536      2022-10-18          1.356851
# 7     AL    1530803      20526      2022-10-18          1.340865
# 8     MO    1660094      21600      2022-10-18          1.301131
# 9     AR     956424      12386      2022-10-18          1.295032
# 10    IN    1930022      24816      2022-10-18          1.285788
# 11    OH    3162278      40037      2022-10-18          1.266081
# 12    CT     907038      11420      2022-10-18          1.259043
# ...

# %%
top_5 = sorted_df.head(5)
top_5
# Out:
#   state  tot_cases  tot_death submission_date  % of cases fatal
# 0    PA    3280190      47442      2022-10-18          1.446319
# 1    MS     930438      12945      2022-10-18          1.391280
# 2    GA    2913382      40448      2022-10-18          1.388352
# 3    AZ    2277635      31455      2022-10-18          1.381038
# 4    NM     623179       8601      2022-10-18          1.380181

# %%
state = top_5["state"]
fatality = top_5["% of cases fatal"]

plt.bar(state, fatality, alpha = 0.8)
plt.title("States with Highest Fatality Rates as Portion of Cases")
plt.xlabel("State")
plt.ylabel("% of COVID-19 cases fatal")

plt.show()

# %%
bottom_5 = sorted_df.tail(5)
bottom_5
# Out:
#    state  tot_cases  tot_death submission_date  % of cases fatal
# 46    NH     354443       2721      2022-10-18          0.767683
# 47    VT     133845        700      2022-10-18          0.522993
# 48    UT    1041651       5034      2022-10-18          0.483271
# 49    HI     349598       1687      2022-10-18          0.482554
# 50    AK     284076       1356      2022-10-18          0.477337

# %%
state = bottom_5["state"]
fatality = bottom_5["% of cases fatal"]

plt.bar(state, fatality, alpha = 0.8)
plt.title("States with Lowest Fatality Rates as Portion of Cases")
plt.xlabel("State")
plt.ylabel("% of COVID-19 cases fatal")

plt.show()

# %%
top_5_pops = [12972008, 6177957, 10912876, 7359197, 2113344]
top_5_medicare = [10216, 9994, 10274, 9614, 8343]
top_5_uninsured = [5.4, 9.3, 12.7, 10.6, 10.0]

top_5["Population (2022)"] = top_5_pops
top_5["Medicare Spending ($/yr)"] = top_5_medicare
top_5["% of Pop. Uninsured"] = top_5_uninsured

top_5
# Out:
# /var/folders/hc/1c1sdxpx7yv2_xbpx2wrxyb80000gn/T/ipykernel_4917/3640595902.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_5["Population (2022)"] = top_5_pops
# /var/folders/hc/1c1sdxpx7yv2_xbpx2wrxyb80000gn/T/ipykernel_4917/3640595902.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_5["Medicare Spending ($/yr)"] = top_5_medicare
# /var/folders/hc/1c1sdxpx7yv2_xbpx2wrxyb80000gn/T/ipykernel_4917/3640595902.py:7: SettingWithCopyWarning:
# ...

# %%
top_meanpop = np.mean(top_5["Population (2022)"])
top_meanmed = np.mean(top_5["Medicare Spending ($/yr)"])
top_meanuninsured = np.mean(top_5["% of Pop. Uninsured"])

print(f"The mean population is {top_meanpop}.")
print(f"The mean spending on Medicare per year is ${top_meanmed}.")
print(f"The mean % of the state's population that are uninsured is %{top_meanuninsured}.")
# Out:
# The mean population is 7907076.4.
# The mean spending on Medicare per year is $9688.2.
# The mean % of the state's population that are uninsured is %9.6.

# %%
bottom_5_pops = [1395231, 647064, 3380800, 1440196, 733583]
bottom_5_medicare = [9256, 8822, 9019, 7208, 9246]
bottom_5_uninsured = [5.0, 3.3, 9.1, 3.7, 10.8]

bottom_5["Population (2022)"] = bottom_5_pops
bottom_5["Medicare Spending ($/yr)"] = bottom_5_medicare
bottom_5["% of Pop. Uninsured"] = bottom_5_uninsured

bottom_5
# Out:
# /var/folders/hc/1c1sdxpx7yv2_xbpx2wrxyb80000gn/T/ipykernel_4917/2295626659.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bottom_5["Population (2022)"] = bottom_5_pops
# /var/folders/hc/1c1sdxpx7yv2_xbpx2wrxyb80000gn/T/ipykernel_4917/2295626659.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bottom_5["Medicare Spending ($/yr)"] = bottom_5_medicare
# /var/folders/hc/1c1sdxpx7yv2_xbpx2wrxyb80000gn/T/ipykernel_4917/2295626659.py:7: SettingWithCopyWarning:
# ...

# %%
bottom_meanpop = np.mean(bottom_5["Population (2022)"])
bottom_meanmed = np.mean(bottom_5["Medicare Spending ($/yr)"])
bottom_meanuninsured = np.mean(bottom_5["% of Pop. Uninsured"])

print(f"The mean population is {bottom_meanpop}.")
print(f"The mean spending on Medicare per year is ${bottom_meanmed}.")
print(f"The mean % of the state's population that are uninsured is %{bottom_meanuninsured}.")
# Out:
# The mean population is 1519374.8.
# The mean spending on Medicare per year is $8710.2.
# The mean % of the state's population that are uninsured is %6.38.
